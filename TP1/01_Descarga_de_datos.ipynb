# %% [markdown]
# <a href="https://colab.research.google.com/github/danielruizuleta/Proyecto-Grupo-Argos/blob/main/TP1/01_Descarga_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar Librerias

# %%
from pathlib import Path

# %%
import pandas as pd

# %%
alpha_df = pd.read_csv("dataset_alpha_betha.csv", low_memory=False)

# %%
alpha_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   autoID            7043 non-null   object
#  1   SeniorCity        7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   Service1          7043 non-null   object
#  5   Service2          7043 non-null   object
#  6   Security          7043 non-null   object
#  7   OnlineBackup      7043 non-null   object
#  8   DeviceProtection  7043 non-null   object
#  9   TechSupport       7043 non-null   object
#  10  Contract          7043 non-null   object
#  11  PaperlessBilling  7043 non-null   object
#  12  PaymentMethod     7043 non-null   object
#  13  Charges           7043 non-null   float64
#  14  Demand            7043 non-null   object
#  15  Class             7043 non-null   object
# ...

# %%
alpha_df.sample(10)
# Out:
#           autoID  SeniorCity Partner Dependents Service1          Service2  \
# 3755  8443-ZRDBZ           0      No         No      Yes               Yes
# 6891  7853-OETYL           0     Yes         No       No  No phone service
# 1432  9046-DQMTP           0      No         No      Yes                No
# 274   5940-AHUHD           0      No         No      Yes                No
# 180   6317-YPKDH           0      No         No       No  No phone service
# 5479  8990-ZXLSU           0      No         No      Yes                No
# 1748  8540-ZQGEA           0     Yes         No      Yes                No
# 236   0621-JFHOL           0      No         No       No  No phone service
# 4106  9189-JWSHV           1     Yes         No      Yes               Yes
# 1980  1960-UYCNN           0      No         No      Yes               Yes
#
#                  Security         OnlineBackup     DeviceProtection  \
# 3755                   No                   No                   No
# ...

# %%
alpha_df.columns
# Out:
# Index(['autoID', 'SeniorCity', 'Partner', 'Dependents', 'Service1', 'Service2',
#        'Security', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges', 'Demand',
#        'Class', 'Class_encoded'],
#       dtype='object')

# %%
alpha_df.describe()
# Out:
#         SeniorCity      Charges  Class_encoded
# count  7043.000000  7043.000000    7043.000000
# mean      0.162147    64.761692       0.265370
# std       0.368612    30.090047       0.441561
# min       0.000000    18.250000       0.000000
# 25%       0.000000    35.500000       0.000000
# 50%       0.000000    70.350000       0.000000
# 75%       0.000000    89.850000       1.000000
# max       1.000000   118.750000       1.000000

# %%
from pathlib import Path
import pandas as pd


alpha_final_df = pd.read_csv('dataset_alpha_betha.csv')


DATA_DIR = Path.cwd() / "data" / "01_raw"
file_path = DATA_DIR / "dataset_alpha_betha.csv"

DATA_DIR.mkdir(parents=True, exist_ok=True)

# Guardar el DataFrame en formato CSV
alpha_df.to_csv(file_path, index=False)

print(f"Archivo guardado en: {file_path}")
# Out:
# Archivo guardado en: /content/data/01_raw/dataset_alpha_betha.csv
